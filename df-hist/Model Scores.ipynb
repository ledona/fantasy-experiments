# %%
# Load data
import pandas as pd

contest_dfs = {service: pd.read_csv(f"{service}.contest.csv")
               for service in ['fanduel', 'draftkings', 'yahoo']}
contest_dfs
# Out:
# {'fanduel':                                   contest_id        date sport  \
#  0    https://www.fanduel.com/entry/ESWRFIHDH  2021-01-09   nba
#  1    https://www.fanduel.com/entry/EVOEPCOMB  2021-01-09   nfl
#  2    https://www.fanduel.com/entry/ERGYNLAON  2021-01-09   nba
#  3    https://www.fanduel.com/entry/BMXUDEJBX  2020-12-27   nfl
#  4    https://www.fanduel.com/entry/EPDHCTBVH  2020-12-27   nfl
#  ..                                       ...         ...   ...
#  330  https://www.fanduel.com/entry/CKOGYTQOL  2020-01-03   nhl
#  331  https://www.fanduel.com/entry/CNFUKGRCH  2020-01-03   nhl
#  332  https://www.fanduel.com/entry/CTCTNSSOQ  2020-01-02   nhl
#  333  https://www.fanduel.com/entry/DIPYRBHFO  2020-01-02   nhl
#  334  https://www.fanduel.com/entry/AVJTFKVFO  2020-01-02   nhl
#
#                                              title   fee  entries winners  \
#  0          50/50 League ($1 - Top 50% Win) (Main)  1.00      100      39
# ...
